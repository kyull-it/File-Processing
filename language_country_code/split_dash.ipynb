# %%
import pandas as pd

# %%
df = pd.read_excel('code.xlsx', sheet_name = "Sheet1")
df.head()
# Out:
#          Country  Language Two Letter Three Letter  Number
# 0    Afghanistan    Pashto      ps-AF       ps-AFG    1123
# 1    Afghanistan   Persian      fa-AF       fa-AFG    4096
# 2    Afghanistan     Uzbek      uz-AF       uz-AFG    4096
# 3  Åland Islands   Swedish      sv-AX       sv-ALA    4096
# 4        Albania  Albanian      sq-AL       sq-ALB    1052

# %%
temp = list(df["Two Letter"])
# Out:
# ['ps-AF',
#  'fa-AF',
#  'uz-AF',
#  'sv-AX',
#  'sq-AL',
#  'en-AL',
#  'ar-DZ',
#  'fr-DZ',
#  'kab-DZ',
#  'en-AS',
#  'ca-AD',
#  'en-AD',
#  'ln-AO',
#  'pt-AO',
#  'en-AI',
#  'es-AI',
#  'en-AG',
#  'es-AG',
#  'en-AR',
#  'es-AR',
#  'hy-AM',
#  'nl-AW',
#  'es-AW',
#  'en-AU',
#  'en-AT',
#  'de-AT',
#  'az-AZ',
#  'az-AZ',
#  'en-BS',
#  'es-BS',
#  'ar-BH',
#  'bn-BD',
#  'ccp-BD',
#  'en-BD',
#  'en-BB',
#  'es-BB',
#  'be-BY',
#  'ru-BY',
#  'nl-BE',
#  'en-BE',
#  'fr-BE',
#  'de-BE',
#  'wa-BE',
#  'en-BZ',
#  'es-BZ',
#  'fr-BJ',
#  'yo-BJ',
#  'en-BM',
#  'es-BM',
#  'dz-BT',
#  'qu-BO',
#  'es-BO',
#  'bs-BA',
#  'bs-BA',
#  'hr-BA',
#  'en-BA',
#  'sr-BA',
#  'sr-BA',
#  'en-BW',
#  'tn-BW',
#  'en-BR',
#  'pt-BR',
#  'es-BR',
#  'en-IO',
#  'en-VG',
#  'es-VG',
#  'ms-BN',
#  'ms-BN',
#  'bg-BG',
#  'en-BG',
#  'fr-BF',
#  'ff-BF',
#  'en-BI',
#  'fr-BI',
#  'rn-BI',
#  'km-KH',
#  'agq-CM',
#  'ksf-CM',
#  'bas-CM',
#  'dua-CM',
#  'en-CM',
#  'ewo-CM',
# ...

# %%
lan = []
country = []

for i in range(0, len(temp)):
#     print(temp[i])
    temp2 = temp[i].split('-')
#     print(temp2)
    lan.append(temp2[0])
    country.append(temp2[1])
    
new_df = pd.DataFrame(
    {'language_code': lan,
     'country_code': country
    })

new_df = pd.concat

new_df.head()
# Out:
#   language_code country_code
# 0            ps           AF
# 1            fa           AF
# 2            uz           AF
# 3            sv           AX
# 4            sq           AL

# %%
new_df.to_excel('code_list.xlsx')
